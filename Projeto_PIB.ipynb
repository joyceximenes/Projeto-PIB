# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
dados = pd.read_excel('/content/drive/MyDrive/Study analise de dados/Data Viking/Projeto PIB/Dados_Pib.xlsx')
dados.head()
# Out:
#   Territorialidades   Ano  PIB per capita
# 0            Brasil  2013           22.20
# 1              Acre  2013           12.37
# 2           Alagoas  2013            9.45
# 3             Amapá  2013           14.53
# 4          Amazonas  2013           18.25

# %%
dados.shape
# Out:
# (112, 3)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Territorialidades  112 non-null    object
#  1   Ano                112 non-null    int64
#  2   PIB per capita     112 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.8+ KB

# %%
dados.groupby(by = ['Territorialidades', 'PIB per capita']).mean()
# Out:
#                                      Ano
# Territorialidades PIB per capita
# Acre              11.18           2016.0
#                   12.24           2015.0
#                   12.37           2013.0
#                   13.41           2014.0
# Alagoas           9.45            2013.0
# ...                                  ...
# São Paulo         33.22           2014.0
# Tocantins         13.47           2013.0
#                   13.68           2016.0
#                   13.77           2014.0
#                   13.79           2015.0
#
# [112 rows x 1 columns]

# %% [markdown]
# **grids**

# %%
fundo = '#f5f5f5'

grid_graficos = sns.FacetGrid(dados, col = 'Territorialidades', hue = 'Territorialidades', col_wrap=4) # coluna, segmento e num de colunas

# Adicionar grafico linhas em cada gráfico
grid_graficos = grid_graficos.map(plt.plot, 'Ano', 'PIB per capita') # map adiciona uma função especifica, que nesse caso é um grafico ano x pib

# Adiconar uma sombra + Ajuste do titulo
grid_graficos = grid_graficos.map( plt.fill_between,  'Ano', 'PIB per capita', alpha=0.2).set_titles('{col_name} Territorialidades')

# Filtrar o titulo
grid_graficos = grid_graficos.set_titles('{col_name}')

# Adicionar um subtitulo
grid_graficos = grid_graficos.fig.suptitle('Evolução da Renda per capita por Estado')

# Ajustando
plt.subplots_adjust( top=0.92 ) # começa a partir dessa posição
